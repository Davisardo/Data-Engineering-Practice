# %% [markdown]
# # 5.3 - API Examples
#
# Hands-on Lab: API Examples — RandomUser and Fruityvice API
#
# ## Tujuan
# - Load dan pakai RandomUser API lewat library `randomuser`
# - Load dan pakai Fruityvice API lewat `requests`
# - Load dan pakai Open-Joke-API lewat `requests`

# %%
# %pip install randomuser --break-system-packages
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5134 sha256=acaf315f14b72f7790c12b8322e212a3ddc339ea62b4427eaf04cd96c0f37ed8
#   Stored in directory: c:\users\asus vivobook\appdata\local\pip\cache\wheels\1b\79\19\d8c0d6163d7c537b588138c2ee5ff37dc915b5ae0420a6617e
# Successfully built randomuser
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10)
some_list

# %%
name = r.get_full_name()
name
# Out:
# 'Herbert Kürschner'

# %%
for user in some_list:
    print(user.get_full_name(), " ", user.get_email())
# Out:
# Heinz Dieter Jung   heinzdieter.jung@example.com
# Mandy Wade   mandy.wade@example.com
# حامد كامياران   hmd.kmyrn@example.com
# Cristina Garcia   cristina.garcia@example.com
# Inaya Rey   inaya.rey@example.com
# Adolf Nicolas   adolf.nicolas@example.com
# Alivar da Luz   alivar.daluz@example.com
# Angel Dufour   angel.dufour@example.com
# Axel Dufour   axel.dufour@example.com
# Maddison Hanson   maddison.hanson@example.com

# %% [markdown]
# ## Exercise 1
# Generate foto dari 10 user random.

# %%
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/11.jpg
# https://randomuser.me/api/portraits/women/90.jpg
# https://randomuser.me/api/portraits/men/54.jpg
# https://randomuser.me/api/portraits/women/27.jpg
# https://randomuser.me/api/portraits/women/82.jpg
# https://randomuser.me/api/portraits/men/41.jpg
# https://randomuser.me/api/portraits/men/2.jpg
# https://randomuser.me/api/portraits/men/62.jpg
# https://randomuser.me/api/portraits/men/80.jpg
# https://randomuser.me/api/portraits/women/55.jpg

# %%
def get_users():
    users = []

    for user in RandomUser.generate_users(10):
        users.append({
            "Name": user.get_full_name(),
            "Gender": user.get_gender(),
            "City": user.get_city(),
            "State": user.get_state(),
            "Email": user.get_email(),
            "DOB": user.get_dob(),
            "Picture": user.get_picture()
        })

    return pd.DataFrame(users)

# %%
get_users()
# Out:
#               Name  Gender                        City         State  \
# 0    Elisa Velasco  female                   Santander     Andalucía
# 1     نازنین جعفری  female                       سنندج  خراسان شمالی
# 2     Diego Dumont    male                     Le Mans    Martinique
# 3   Julian Lyngvær    male                    Fuglevik       Hedmark
# 4      Gabriel Gil    male  Las Palmas de Gran Canaria        Aragón
# 5    Samantha Boyd  female                 Van Alstyne         Idaho
# 6     Zará Martins    male                     Ibirité         Goiás
# 7  André Chevalier    male                Wiesendangen           Uri
# 8     Eetu Huhtala    male                      Kannus  Ostrobothnia
# 9  Martyn Marissen    male                    Oostzaan       Drenthe
#
#                          Email                       DOB  \
# 0    elisa.velasco@example.com  1992-10-26T15:48:27.881Z
# 1     nznyn.jaafry@example.com  1959-01-17T16:17:03.251Z
# ...

# %%
df1 = pd.DataFrame(get_users())

# %% [markdown]
# ## Example 2: Fruityvice API

# %%
import requests
import json

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")

# %%
results = json.loads(data.text)

# %%
pd.DataFrame(results)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
df2 = pd.json_normalize(results)
df2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']), (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
# Cari tahu berapa kalori dalam sebuah pisang (Banana).

# %%
cal_banana = df2.loc[df2["name"] == 'Banana']
cal_banana.iloc[0]['nutritions.calories']
# Out:
# np.int64(96)

# %% [markdown]
# ## Exercise 3: Official Joke API
#
# API ini mengembalikan lelucon random. URL berikut mengambil 10 lelucon random.

# %%
data2 = requests.get("https://official-joke-api.appspot.com/jokes/ten")

# %%
results2 = json.loads(data2.text)

# %%
df3 = pd.DataFrame(results2)
df3.drop(columns=["type", "id"], inplace=True)
df3
# Out:
#                                                setup  \
# 0                               What do I look like?
# 1           Where do sheep go to get their hair cut?
# 2                 Do I enjoy making courthouse puns?
# 3                        How do you make holy water?
# 4                  What did the shy pebble wish for?
# 5                        Ever wondered why bees hum?
# 6          What does the mermaid wear to math class?
# 7        Why can't you use "Beef stew"as a password?
# 8  Why do wizards clean their teeth three times a...
# 9           How do you fix a damaged jack-o-lantern?
#
#                                  punchline
# 0                         A JOKE MACHINE!?
# 1                        The baa-baa shop.
# 2                                   Guilty
# 3              You boil the hell out of it
# 4           That she was a little boulder.
# 5  It's because they don't know the words.
# 6                               Algae-bra.
# ...
